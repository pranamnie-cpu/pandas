# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Elite.csv", encoding="latin-1")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               5000 non-null   str
#  1   Model               5000 non-null   str
#  2   Year                5000 non-null   int64
#  3   Country             5000 non-null   str
#  4   Condition           5000 non-null   str
#  5   Engine_Size         5000 non-null   float64
#  6   Horsepower          5000 non-null   int64
#  7   Torque              5000 non-null   int64
#  8   Weight              5000 non-null   int64
#  9   Top_Speed           5000 non-null   int64
#  10  Acceleration_0_100  5000 non-null   float64
#  11  Fuel_Type           5000 non-null   str
#  12  Drivetrain          5000 non-null   str
#  13  Transmission        5000 non-null   str
#  14  Fuel_Efficiency     5000 non-null   float64
#  15  CO2_Emissions       5000 non-null   int64
# ...

# %%
df.head()
# Out:
#        Brand           Model  Year Country Condition  Engine_Size  Horsepower  \
# 0     Nissan            720S  2006    Asia      used          3.7         420
# 1    McLaren     911 Turbo S  2009  Europe       new          5.3        1104
# 2  Chevrolet  M4 Competition  2009     USA       new          5.5         153
# 3    Bugatti          Chiron  1982    Asia      used          5.4         544
# 4     Nissan          Chiron  2022  Europe       new          2.4         980
#
#    Torque  Weight  Top_Speed  ...  Mileage Popularity Safety_Rating  \
# 0     705    1785        238  ...    96664        Low             2
# 1     766     992        386  ...   159630       High             2
# 2    1573    2022        397  ...   111496       High             1
# 3    1009    1091        151  ...   217228       High             2
# 4     693    1232        385  ...   150318        Low             3
#
#   Number_of_Owners  Market_Demand  Insurance_Cost  Production_Units  \
# ...

# %%
df.tail()
# Out:
#         Brand           Model  Year Country Condition  Engine_Size  \
# 4995   Nissan            GT-R  2011     USA      used          3.9
# 4996  McLaren  M4 Competition  2021     USA       new          6.9
# 4997  Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998  Porsche  M4 Competition  2023    Asia       new          7.3
# 4999  McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# 4995        1392     514    1049        284  ...    80352        Low
# 4996         256     662    2131        223  ...   164451       High
# 4997         212     123    2272        289  ...    30314        Low
# 4998        1373     228    1161        204  ...    13144        Low
# 4999        1075    1037    1312        381  ...    57970       High
#
#      Safety_Rating Number_of_Owners  Market_Demand  Insurance_Cost  \
# 4995             1                3         Medium           10428
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Country', 'Condition', 'Engine_Size',
#        'Horsepower', 'Torque', 'Weight', 'Top_Speed', 'Acceleration_0_100',
#        'Fuel_Type', 'Drivetrain', 'Transmission', 'Fuel_Efficiency',
#        'CO2_Emissions', 'Price', 'Mileage', 'Popularity', 'Safety_Rating',
#        'Number_of_Owners', 'Market_Demand', 'Insurance_Cost',
#        'Production_Units', 'Log_Price', 'Log_Mileage', 'Modification'],
#       dtype='str')

# %%
df.shape
# Out:
# (5000, 27)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
df.dtypes
# Out:
# Brand                     str
# Model                     str
# Year                    int64
# Country                   str
# Condition                 str
# Engine_Size           float64
# Horsepower              int64
# Torque                  int64
# Weight                  int64
# Top_Speed               int64
# Acceleration_0_100    float64
# Fuel_Type                 str
# Drivetrain                str
# Transmission              str
# Fuel_Efficiency       float64
# CO2_Emissions           int64
# Price                   int64
# Mileage                 int64
# Popularity                str
# Safety_Rating           int64
# Number_of_Owners        int64
# Market_Demand             str
# Insurance_Cost          int64
# Production_Units        int64
# Log_Price             float64
# Log_Mileage           float64
# Modification              str
# dtype: object

# %%
df.describe()
# Out:
#               Year  Engine_Size   Horsepower       Torque       Weight  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2001.904800     4.828700   822.891600   938.800600  1689.724200
# std      12.873697     1.858353   401.362549   472.954278   465.786421
# min    1980.000000     1.600000   130.000000   120.000000   900.000000
# 25%    1991.000000     3.200000   472.000000   522.000000  1286.000000
# 50%    2002.000000     4.800000   815.500000   948.000000  1684.000000
# 75%    2013.000000     6.500000  1176.000000  1345.000000  2101.000000
# max    2024.000000     8.000000  1521.000000  1758.000000  2499.000000
#
#          Top_Speed  Acceleration_0_100  Fuel_Efficiency  CO2_Emissions  \
# count  5000.000000         5000.000000      5000.000000    5000.000000
# mean    274.857000            4.517280        10.038340     272.695200
# std      72.062214            1.448473         2.881613     100.154245
# ...

# %%
df.isnull()
# Out:
#       Brand  Model   Year  Country  Condition  Engine_Size  Horsepower  \
# 0     False  False  False    False      False        False       False
# 1     False  False  False    False      False        False       False
# 2     False  False  False    False      False        False       False
# 3     False  False  False    False      False        False       False
# 4     False  False  False    False      False        False       False
# ...     ...    ...    ...      ...        ...          ...         ...
# 4995  False  False  False    False      False        False       False
# 4996  False  False  False    False      False        False       False
# 4997  False  False  False    False      False        False       False
# 4998  False  False  False    False      False        False       False
# 4999  False  False  False    False      False        False       False
#
#       Torque  Weight  Top_Speed  ...  Mileage  Popularity  Safety_Rating  \
# ...

# %%
df.isnull().sum()
# Out:
# Brand                    0
# Model                    0
# Year                     0
# Country                  0
# Condition                0
# Engine_Size              0
# Horsepower               0
# Torque                   0
# Weight                   0
# Top_Speed                0
# Acceleration_0_100       0
# Fuel_Type                0
# Drivetrain               0
# Transmission             0
# Fuel_Efficiency          0
# CO2_Emissions            0
# Price                    0
# Mileage                  0
# Popularity               0
# Safety_Rating            0
# Number_of_Owners         0
# Market_Demand            0
# Insurance_Cost           0
# Production_Units         0
# Log_Price                0
# Log_Mileage              0
# Modification          3023
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Model', 'Year', 'Country', 'Condition', 'Engine_Size',
#        'Horsepower', 'Torque', 'Weight', 'Top_Speed', 'Acceleration_0_100',
#        'Fuel_Type', 'Drivetrain', 'Transmission', 'Fuel_Efficiency',
#        'CO2_Emissions', 'Price', 'Mileage', 'Popularity', 'Safety_Rating',
#        'Number_of_Owners', 'Market_Demand', 'Insurance_Cost',
#        'Production_Units', 'Log_Price', 'Log_Mileage', 'Modification'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Country', 'Condition', 'Engine_Size',
#        'Horsepower', 'Torque', 'Weight', 'Top_Speed', 'Acceleration_0_100',
#        'Fuel_Type', 'Drivetrain', 'Transmission', 'Fuel_Efficiency',
#        'CO2_Emissions', 'Price', 'Mileage', 'Popularity', 'Safety_Rating',
#        'Number_of_Owners', 'Market_Demand', 'Insurance_Cost',
#        'Production_Units', 'Log_Price', 'Log_Mileage', 'Modification'],
#       dtype='str')

# %%
df[['Brand','Price']].head(10).head(10)
# Out:
#        Brand   Price
# 0     Nissan   81580
# 1    McLaren  308455
# 2  Chevrolet  420374
# 3    Bugatti  123690
# 4     Nissan   75303
# 5        BMW  478142
# 6    Porsche  398429
# 7     Nissan  133803
# 8  Chevrolet  245162
# 9    Bugatti  451504

# %%
df[['Brand','Model','Year','Price']].sort_values(by='Year').head(10)
# Out:
#              Brand        Model  Year   Price
# 4955  Aston Martin       Chiron  1980  218810
# 1698           BMW  911 Turbo S  1980  174094
# 3896          Ford  911 Turbo S  1980  286395
# 1603       Ferrari         720S  1980  468932
# 1590       Bugatti         GT-R  1980  140444
# 3859           BMW  911 Turbo S  1980  123392
# 1582  Aston Martin      Huracan  1980  129929
# 3227  Aston Martin      488 GTB  1980  219267
# 337           Ford      Huracan  1980  483118
# 2623       Bugatti      Huracan  1980   89177

# %%
mean_P=df['Price'].mean()
print(mean_P)
# Out:
# 262067.3294

# %%
df['Year'].median()
# Out:
# np.float64(2002.0)

# %%
df['Brand'].mode()[0]
# Out:
# 'Ferrari'

# %%
df.groupby("Brand")["Price"].mean()
# Out:
# Brand
# Aston Martin    256236.752437
# BMW             276471.391129
# Bugatti         265088.418146
# Chevrolet       267751.664729
# Ferrari         256136.947467
# Ford            252898.777778
# Lamborghini     259313.717021
# McLaren         267438.755144
# Nissan          259352.085417
# Porsche         260090.085770
# Name: Price, dtype: float64

# %%
df.head(7)
# Out:
#        Brand           Model  Year Country Condition  Engine_Size  Horsepower  \
# 0     Nissan            720S  2006    Asia      used          3.7         420
# 1    McLaren     911 Turbo S  2009  Europe       new          5.3        1104
# 2  Chevrolet  M4 Competition  2009     USA       new          5.5         153
# 3    Bugatti          Chiron  1982    Asia      used          5.4         544
# 4     Nissan          Chiron  2022  Europe       new          2.4         980
# 5        BMW            GT-R  1986  Europe       new          5.4        1091
# 6    Porsche            720S  1988    Asia       new          4.2         810
#
#    Torque  Weight  Top_Speed  ...  Mileage Popularity Safety_Rating  \
# 0     705    1785        238  ...    96664        Low             2
# 1     766     992        386  ...   159630       High             2
# 2    1573    2022        397  ...   111496       High             1
# 3    1009    1091        151  ...   217228       High             2
# ...

# %%
df.shape
# Out:
# (5000, 27)

# %%
df.info
# Out:
# <bound method DataFrame.info of           Brand           Model  Year Country Condition  Engine_Size  \
# 0        Nissan            720S  2006    Asia      used          3.7
# 1       McLaren     911 Turbo S  2009  Europe       new          5.3
# 2     Chevrolet  M4 Competition  2009     USA       new          5.5
# 3       Bugatti          Chiron  1982    Asia      used          5.4
# 4        Nissan          Chiron  2022  Europe       new          2.4
# ...         ...             ...   ...     ...       ...          ...
# 4995     Nissan            GT-R  2011     USA      used          3.9
# 4996    McLaren  M4 Competition  2021     USA       new          6.9
# 4997    Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998    Porsche  M4 Competition  2023    Asia       new          7.3
# 4999    McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Country', 'Condition', 'Engine_Size',
#        'Horsepower', 'Torque', 'Weight', 'Top_Speed', 'Acceleration_0_100',
#        'Fuel_Type', 'Drivetrain', 'Transmission', 'Fuel_Efficiency',
#        'CO2_Emissions', 'Price', 'Mileage', 'Popularity', 'Safety_Rating',
#        'Number_of_Owners', 'Market_Demand', 'Insurance_Cost',
#        'Production_Units', 'Log_Price', 'Log_Mileage', 'Modification'],
#       dtype='str')

# %%
df.tail
# Out:
# <bound method NDFrame.tail of           Brand           Model  Year Country Condition  Engine_Size  \
# 0        Nissan            720S  2006    Asia      used          3.7
# 1       McLaren     911 Turbo S  2009  Europe       new          5.3
# 2     Chevrolet  M4 Competition  2009     USA       new          5.5
# 3       Bugatti          Chiron  1982    Asia      used          5.4
# 4        Nissan          Chiron  2022  Europe       new          2.4
# ...         ...             ...   ...     ...       ...          ...
# 4995     Nissan            GT-R  2011     USA      used          3.9
# 4996    McLaren  M4 Competition  2021     USA       new          6.9
# 4997    Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998    Porsche  M4 Competition  2023    Asia       new          7.3
# 4999    McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# ...

# %%
df.tail()
# Out:
#         Brand           Model  Year Country Condition  Engine_Size  \
# 4995   Nissan            GT-R  2011     USA      used          3.9
# 4996  McLaren  M4 Competition  2021     USA       new          6.9
# 4997  Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998  Porsche  M4 Competition  2023    Asia       new          7.3
# 4999  McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# 4995        1392     514    1049        284  ...    80352        Low
# 4996         256     662    2131        223  ...   164451       High
# 4997         212     123    2272        289  ...    30314        Low
# 4998        1373     228    1161        204  ...    13144        Low
# 4999        1075    1037    1312        381  ...    57970       High
#
#      Safety_Rating Number_of_Owners  Market_Demand  Insurance_Cost  \
# 4995             1                3         Medium           10428
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           Brand           Model  Year Country Condition  Engine_Size  \
# 0        Nissan            720S  2006    Asia      used          3.7
# 1       McLaren     911 Turbo S  2009  Europe       new          5.3
# 2     Chevrolet  M4 Competition  2009     USA       new          5.5
# 3       Bugatti          Chiron  1982    Asia      used          5.4
# 4        Nissan          Chiron  2022  Europe       new          2.4
# ...         ...             ...   ...     ...       ...          ...
# 4995     Nissan            GT-R  2011     USA      used          3.9
# 4996    McLaren  M4 Competition  2021     USA       new          6.9
# 4997    Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998    Porsche  M4 Competition  2023    Asia       new          7.3
# 4999    McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               5000 non-null   str
#  1   Model               5000 non-null   str
#  2   Year                5000 non-null   int64
#  3   Country             5000 non-null   str
#  4   Condition           5000 non-null   str
#  5   Engine_Size         5000 non-null   float64
#  6   Horsepower          5000 non-null   int64
#  7   Torque              5000 non-null   int64
#  8   Weight              5000 non-null   int64
#  9   Top_Speed           5000 non-null   int64
#  10  Acceleration_0_100  5000 non-null   float64
#  11  Fuel_Type           5000 non-null   str
#  12  Drivetrain          5000 non-null   str
#  13  Transmission        5000 non-null   str
#  14  Fuel_Efficiency     5000 non-null   float64
#  15  CO2_Emissions       5000 non-null   int64
# ...

# %%
df[['Brand','Model']]
# Out:
#           Brand           Model
# 0        Nissan            720S
# 1       McLaren     911 Turbo S
# 2     Chevrolet  M4 Competition
# 3       Bugatti          Chiron
# 4        Nissan          Chiron
# ...         ...             ...
# 4995     Nissan            GT-R
# 4996    McLaren  M4 Competition
# 4997    Bugatti     911 Turbo S
# 4998    Porsche  M4 Competition
# 4999    McLaren          Chiron
#
# [5000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Brand                    0
# Model                    0
# Year                     0
# Country                  0
# Condition                0
# Engine_Size              0
# Horsepower               0
# Torque                   0
# Weight                   0
# Top_Speed                0
# Acceleration_0_100       0
# Fuel_Type                0
# Drivetrain               0
# Transmission             0
# Fuel_Efficiency          0
# CO2_Emissions            0
# Price                    0
# Mileage                  0
# Popularity               0
# Safety_Rating            0
# Number_of_Owners         0
# Market_Demand            0
# Insurance_Cost           0
# Production_Units         0
# Log_Price                0
# Log_Mileage              0
# Modification          3023
# dtype: int64

# %%
df.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df.dropna()
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.dropna()
# Out:
#              Brand           Model  Year Country Condition  Engine_Size  \
# 0           Nissan            720S  2006    Asia      used          3.7
# 6          Porsche            720S  1988    Asia       new          4.2
# 7           Nissan            720S  2020     USA       new          7.4
# 12       Chevrolet             DBS  2008  Europe       new          2.1
# 13         Porsche         Huracan  2014  Europe      used          7.0
# ...            ...             ...   ...     ...       ...          ...
# 4991  Aston Martin            720S  1985    Asia       new          4.0
# 4994           BMW          Chiron  2013  Europe      used          7.7
# 4996       McLaren  M4 Competition  2021     USA       new          6.9
# 4998       Porsche  M4 Competition  2023    Asia       new          7.3
# 4999       McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...  Mileage Popularity  \
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Country', 'Condition', 'Engine_Size',
#        'Horsepower', 'Torque', 'Weight', 'Top_Speed', 'Acceleration_0_100',
#        'Fuel_Type', 'Drivetrain', 'Transmission', 'Fuel_Efficiency',
#        'CO2_Emissions', 'Price', 'Mileage', 'Popularity', 'Safety_Rating',
#        'Number_of_Owners', 'Market_Demand', 'Insurance_Cost',
#        'Production_Units', 'Log_Price', 'Log_Mileage', 'Modification'],
#       dtype='str')

# %%
df['Top_Speed'].min()
# Out:
# np.int64(150)

# %%
df["Brand"].value_counts()
# Out:
# Brand
# Ferrari         533
# Chevrolet       516
# Porsche         513
# Aston Martin    513
# Bugatti         507
# BMW             496
# McLaren         486
# Ford            486
# Nissan          480
# Lamborghini     470
# Name: count, dtype: int64

# %%
df[df['Brand']=='BMW'].sort_values(by='Engine_Size')
# Out:
#      Brand         Model  Year Country Condition  Engine_Size  Horsepower  \
# 3233   BMW       488 GTB  2004  Europe       new          1.6         783
# 1186   BMW        Chiron  2008    Asia      used          1.6         919
# 4425   BMW       488 GTB  2016    Asia      used          1.6         753
# 4093   BMW       Huracan  2009    Asia       new          1.6         958
# 4234   BMW  Corvette Z06  1988     USA       new          1.6        1334
# ...    ...           ...   ...     ...       ...          ...         ...
# 1625   BMW        Chiron  2021     USA       new          8.0         591
# 3563   BMW       Huracan  1980     USA       new          8.0        1283
# 2970   BMW          GT-R  1989  Europe       new          8.0         819
# 4192   BMW    Mustang GT  1981  Europe   salvage          8.0         216
# 4793   BMW          GT-R  1998  Europe       new          8.0         919
#
#       Torque  Weight  Top_Speed  ...  Mileage Popularity Safety_Rating  \
# ...
